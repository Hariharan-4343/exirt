# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/final exit t es/Employee.csv'

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
# ...

# %%
df.tail()
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 74493        16243   56  Female                42  Healthcare            7830
# 74494        47175   30  Female                15   Education            3856
# 74495        12409   52    Male                 5   Education            5654
# 74496         9554   18    Male                 4   Education            5276
# 74497        73042   59  Female                48   Education            3774
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 74493              Poor           Medium            Average
# 74494              Good           Medium            Average
# 74495              Good        Very High      Below Average
# 74496              Fair             High            Average
# 74497              Good             High      Below Average
#
#        Number of Promotions Overtime  Distance from Home    Education Level  \
# ...

# %%
df.head(50)
# Out:
#     Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0          8410   31    Male                19   Education            5390
# 1         64756   59  Female                 4       Media            5534
# 2         30257   24  Female                10  Healthcare            8159
# 3         65791   36  Female                 7   Education            3989
# 4         65026   56    Male                41   Education            4821
# 5         24368   38  Female                 3  Technology            9977
# 6         64970   47    Male                23   Education            3681
# 7         36999   48    Male                16     Finance           11223
# 8         32714   57    Male                44   Education            3773
# 9         15944   24  Female                 1  Healthcare            7319
# 10        29972   30  Female                12   Education            5443
# ...

# %%
df_emp=df.copy()

# %%
#santiy check of data

# %%
# Set the option to display all columns
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0             8410   31    Male                19   Education            5390
# 1            64756   59  Female                 4       Media            5534
# 2            30257   24  Female                10  Healthcare            8159
# 3            65791   36  Female                 7   Education            3989
# 4            65026   56    Male                41   Education            4821
# ...            ...  ...     ...               ...         ...             ...
# 74493        16243   56  Female                42  Healthcare            7830
# 74494        47175   30  Female                15   Education            3856
# 74495        12409   52    Male                 5   Education            5654
# 74496         9554   18    Male                 4   Education            5276
# 74497        73042   59  Female                48   Education            3774
#
# ...

# %%
df=pd.DataFrame(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74498 entries, 0 to 74497
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               74498 non-null  int64
#  1   Age                       74498 non-null  int64
#  2   Gender                    74498 non-null  object
#  3   Years at Company          74498 non-null  int64
#  4   Job Role                  74498 non-null  object
#  5   Monthly Income            74498 non-null  int64
#  6   Work-Life Balance         74494 non-null  object
#  7   Job Satisfaction          74498 non-null  object
#  8   Performance Rating        74494 non-null  object
#  9   Number of Promotions      74493 non-null  float64
#  10  Overtime                  74498 non-null  object
#  11  Distance from Home        74498 non-null  int64
#  12  Education Level           74493 non-null  object
# ...

# %%
df.describe()
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  74498.000000  74498.000000      74498.000000    74498.000000
# mean   37249.500000     38.529746         15.721603     7299.379514
# std    21505.864514     12.083456         11.223744     2152.508566
# min        1.000000     18.000000          1.000000     1226.000000
# 25%    18625.250000     28.000000          7.000000     5652.000000
# 50%    37249.500000     39.000000         13.000000     7348.000000
# 75%    55873.750000     49.000000         23.000000     8876.000000
# max    74498.000000     59.000000         51.000000    16149.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          74493.000000        74498.000000          74492.000000
# mean               0.832978           49.991584              1.650365
# std                0.995303           28.513611              1.553660
# min                0.000000            1.000000              0.000000
# ...

# %%
#To find missing values in Datasets

# %%
df.isna().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           4
# Job Satisfaction            0
# Performance Rating          4
# Number of Promotions        5
# Overtime                    0
# Distance from Home          0
# Education Level             5
# Marital Status              4
# Number of Dependents        6
# Job Level                   5
# Company Size                2
# Company Tenure              0
# Remote Work                 3
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        2
# Attrition                   0
# dtype: int64

# %%
#finding percentage of missing values

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# Employee ID                 0.000000
# Age                         0.000000
# Gender                      0.000000
# Years at Company            0.000000
# Job Role                    0.000000
# Monthly Income              0.000000
# Work-Life Balance           0.005369
# Job Satisfaction            0.000000
# Performance Rating          0.005369
# Number of Promotions        0.006712
# Overtime                    0.000000
# Distance from Home          0.000000
# Education Level             0.006712
# Marital Status              0.005369
# Number of Dependents        0.008054
# Job Level                   0.006712
# Company Size                0.002685
# Company Tenure              0.000000
# Remote Work                 0.004027
# Leadership Opportunities    0.000000
# Innovation Opportunities    0.000000
# Company Reputation          0.000000
# Employee Recognition        0.002685
# Attrition                   0.000000
# dtype: float64

# %%
#finding duplicated values

# %%
print(f'Duplicates: {df.duplicated().sum()}')
# Out:
# Duplicates: 0

# %%
#identifying garbage values from Data set

# %%
for i in df.select_dtypes(include='object').columns:
  print(df[i].value_counts())
  print("***"*10)
# Out:
# Gender
# Male      40826
# Female    33672
# Name: count, dtype: int64
# ******************************
# Job Role
# Technology    19322
# Healthcare    17074
# Education     15658
# Media         11996
# Finance       10448
# Name: count, dtype: int64
# ******************************
# Work-Life Balance
# Good         28157
# Fair         22528
# Excellent    13431
# Poor         10378
# Name: count, dtype: int64
# ******************************
# Job Satisfaction
# High         37245
# Very High    15079
# Medium       14717
# Low           7457
# Name: count, dtype: int64
# ******************************
# Performance Rating
# Average          44716
# High             14910
# Below Average    11139
# Low               3729
# Name: count, dtype: int64
# ******************************
# Overtime
# No     50157
# Yes    24341
# Name: count, dtype: int64
# ******************************
# Education Level
# Bachelor’s Degree    22331
# Associate Degree     18648
# ...

# %%
#exploratory data analysis

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#descriptive statistics

# %%
df.describe().T
# Out:
#                         count          mean           std     min       25%  \
# Employee ID           74498.0  37249.500000  21505.864514     1.0  18625.25
# Age                   74498.0     38.529746     12.083456    18.0     28.00
# Years at Company      74498.0     15.721603     11.223744     1.0      7.00
# Monthly Income        74498.0   7299.379514   2152.508566  1226.0   5652.00
# Number of Promotions  74493.0      0.832978      0.995303     0.0      0.00
# Distance from Home    74498.0     49.991584     28.513611     1.0     25.00
# Number of Dependents  74492.0      1.650365      1.553660     0.0      0.00
# Company Tenure        74498.0     55.727456     25.399349     2.0     36.00
#
#                           50%       75%      max
# Employee ID           37249.5  55873.75  74498.0
# Age                      39.0     49.00     59.0
# Years at Company         13.0     23.00     51.0
# Monthly Income         7348.0   8876.00  16149.0
# ...

# %%
#descriptive statistics of objet colmnss

# %%
df.describe(include='object').T
# Out:
#                           count unique                top   freq
# Gender                    74498      2               Male  40826
# Job Role                  74498      5         Technology  19322
# Work-Life Balance         74494      4               Good  28157
# Job Satisfaction          74498      4               High  37245
# Performance Rating        74494      4            Average  44716
# Overtime                  74498      2                 No  50157
# Education Level           74493      5  Bachelor’s Degree  22331
# Marital Status            74494      3            Married  37417
# Job Level                 74493      3              Entry  29778
# Company Size              74496      3             Medium  37230
# Remote Work               74495      2                 No  60297
# Leadership Opportunities  74498      2                 No  70845
# Innovation Opportunities  74498      2                 No  62394
# ...

# %%
#histogram to understand the distribution

# %%
for i in df.select_dtypes(include="number").columns:
  sns.histplot(data=df,x=i,kde=True)
  plt.show()

# %%
#box plot identify outliers

# %%
for i in df.select_dtypes(include="number").columns:
  sns.boxplot(data=df,x=i)
  plt.show()

# %%
def dist_box(data):
 # function plots a combined graph for univariate analysis of continous variable
 #to check spread, central tendency , dispersion and outliers
    Name=data.name.upper()
    fig,(ax_box,ax_dis)  =plt.subplots(nrows=2,sharex=True,gridspec_kw = {"height_ratios": (.25, .75)},figsize=(8, 5))
    mean=data.mean()
    median=data.median()
    mode=data.mode().tolist()[0]
    sns.set_theme(style="white")
    fig.suptitle("SPREAD OF DATA FOR "+ Name  , fontsize=18, fontweight='bold')
    sns.boxplot(x=data,showmeans=True, orient='h',color="teal",ax=ax_box)
    ax_box.set(xlabel='')
     # just trying to make visualisation better. This will set background to white
    sns.despine(top=True,right=True,left=True) # to remove side line from graph
    sns.distplot(data,kde=False,color='purple',ax=ax_dis)
    ax_dis.axvline(mean, color='r', linestyle='--',linewidth=2)
    ax_dis.axvline(median, color='g', linestyle='-',linewidth=2)
    ax_dis.axvline(mode, color='y', linestyle='-',linewidth=2)
    plt.legend({'Mean':mean,'Median':median,'Mode':mode})

# %%
#select all quantitative columns for checking the spread
list_col=  df_emp.select_dtypes(include='number').columns.to_list()
for i in range(len(list_col)):
    dist_box(df_emp[list_col[i]])

# %%
#heatmap for correlation

# %%
df_tour_numeric = df_emp.select_dtypes(include='number')
sns.set_palette(sns.color_palette("Set2", 8))
plt.figure(figsize=(15,10))
sns.heatmap(df_tour_numeric.corr(),annot=True)
plt.show()

# %%
#scatter plot to understand the relationship

# %%
def plot(x,target='Attrition'):
    fig,axs = plt.subplots(2,2,figsize=(12,10))
    axs[0, 0].set_title(f'Distribution of {x} \n of a customer who had Not taken Product',fontsize=12,fontweight='bold')
    sns.distplot(df_emp[(df_emp[target] == 0)][x],ax=axs[0,0],color='teal')
    axs[0, 1].set_title(f"Distribution of {x}\n of a customer who had taken Product",fontsize=12,fontweight='bold')
    sns.distplot(df_emp[(df_emp[target] == 1)][x],ax=axs[0,1],color='orange')
    axs[1,0].set_title(f'Boxplot of {x} w.r.t Product taken',fontsize=12,fontweight='bold')

    line = plt.Line2D((.1,.9),(.5,.5), color='grey', linewidth=1.5,linestyle='--')
    fig.add_artist(line)

    # Use keyword arguments to specify data and grouping
    sns.boxplot(x=df_emp[target], y=df_emp[x], ax=axs[1,0],palette='gist_rainbow',showmeans=True)
    axs[1,1].set_title(f'Boxplot of {x} w.r.t Product Taken - Without outliers',fontsize=12,fontweight='bold')
    # Use keyword arguments here as well
    sns.boxplot(x=df_emp[target], y=df_emp[x], ax=axs[1,1],showfliers=False,palette='gist_rainbow',showmeans=True)
    sns.despine(top=True,right=True,left=True) # to remove side line from graph
    plt.tight_layout(pad=4)
    plt.show()

# %%
list_col=df_emp.select_dtypes(include='number').columns.to_list()
#print(list_col)
#plt.figure(figsize=(14,23))
for j in range(len(list_col)):
   plot(list_col[j])

# %%
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
# ...

# %%
#correlation with heat map to interpret relationship and multicolliniarity

# %%
df.select_dtypes(include="number").corr()
# Out:
#                       Employee ID       Age  Years at Company  Monthly Income  \
# Employee ID              1.000000  0.003534          0.000441        0.000331
# Age                      0.003534  1.000000          0.537318       -0.001750
# Years at Company         0.000441  0.537318          1.000000       -0.005971
# Monthly Income           0.000331 -0.001750         -0.005971        1.000000
# Number of Promotions     0.006378  0.000655          0.000942        0.005690
# Distance from Home       0.008186 -0.004586         -0.004835       -0.001910
# Number of Dependents    -0.004032  0.003650          0.004393        0.001466
# Company Tenure          -0.003281  0.236337          0.442580       -0.006911
#
#                       Number of Promotions  Distance from Home  \
# Employee ID                       0.006378            0.008186
# Age                               0.000655           -0.004586
# Years at Company                  0.000942           -0.004835
# ...

# %%
s=df.select_dtypes(include="number").corr()

# %%
# Make sure you have imported the necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame, calculate the correlation matrix
s = df.select_dtypes(include="number").corr()

# Create the heatmap
plt.figure(figsize=(15,15))
sns.heatmap(s, annot=True)
plt.show()

# %%
#missing value treatmente

# %%
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
# ...

# %%
df.tail()
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 74493        16243   56  Female                42  Healthcare            7830
# 74494        47175   30  Female                15   Education            3856
# 74495        12409   52    Male                 5   Education            5654
# 74496         9554   18    Male                 4   Education            5276
# 74497        73042   59  Female                48   Education            3774
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 74493              Poor           Medium            Average
# 74494              Good           Medium            Average
# 74495              Good        Very High      Below Average
# 74496              Fair             High            Average
# 74497              Good             High      Below Average
#
#        Number of Promotions Overtime  Distance from Home    Education Level  \
# ...

# %%
df.isnull().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           4
# Job Satisfaction            0
# Performance Rating          4
# Number of Promotions        5
# Overtime                    0
# Distance from Home          0
# Education Level             5
# Marital Status              4
# Number of Dependents        6
# Job Level                   5
# Company Size                2
# Company Tenure              0
# Remote Work                 3
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        2
# Attrition                   0
# dtype: int64

# %%
#median for numerical column

# %%
for i in ["Number of Promotions","Number of Dependents"]:
  df[i].fillna(df[i].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           4
# Job Satisfaction            0
# Performance Rating          4
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             5
# Marital Status              4
# Number of Dependents        0
# Job Level                   5
# Company Size                2
# Company Tenure              0
# Remote Work                 3
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        2
# Attrition                   0
# dtype: int64

# %%
for i in ["Work-Life Balance","Performance Rating","Education Level","Marital Status","Job Level","Company Size","Remote Work","Employee Recognition"]:
  df[i].fillna(df[i].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %%
from sklearn.impute import KNNImputer
imputer=KNNImputer()

# %%
for i in df.select_dtypes(include="number").columns:
  df[i]=imputer.fit_transform(df[[i]])

# %%
#outliers treatment

# %%
#there are outliers in the boxplot

# %%
# Identify outliers using Z-score
from scipy import stats
import numpy as np  # Import NumPy and give it the alias 'np'

z_scores = np.abs(stats.zscore(df.select_dtypes(include=[np.number])))
outliers_z = (z_scores > 3).all(axis=1)
df_outliers_z = df[outliers_z]
print("Outliers using Z-score:")
print(df_outliers_z)
# Out:
# Outliers using Z-score:
# Empty DataFrame
# Columns: [Employee ID, Age, Gender, Years at Company, Job Role, Monthly Income, Work-Life Balance, Job Satisfaction, Performance Rating, Number of Promotions, Overtime, Distance from Home, Education Level, Marital Status, Number of Dependents, Job Level, Company Size, Company Tenure, Remote Work, Leadership Opportunities, Innovation Opportunities, Company Reputation, Employee Recognition, Attrition]
# Index: []

# %%
# Identify outliers using IQR
def detect_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    return df[(df[column] < (Q1 - 1.5 * IQR)) | (df[column] > (Q3 + 1.5 * IQR))]

# %%
outliers_iqr_age = detect_outliers_iqr(df, 'Age')
print(outliers_iqr_age)
# Out:
# Empty DataFrame
# Columns: [Employee ID, Age, Gender, Years at Company, Job Role, Monthly Income, Work-Life Balance, Job Satisfaction, Performance Rating, Number of Promotions, Overtime, Distance from Home, Education Level, Marital Status, Number of Dependents, Job Level, Company Size, Company Tenure, Remote Work, Leadership Opportunities, Innovation Opportunities, Company Reputation, Employee Recognition, Attrition]
# Index: []

# %%
outliers_iqr_age = detect_outliers_iqr(df, 'Monthly Income')
print(outliers_iqr_age)
# Out:
#        Employee ID   Age  Gender  Years at Company    Job Role  \
# 387        46092.0  24.0  Female              14.0     Finance
# 1776        6468.0  40.0    Male              25.0  Technology
# 3521       71311.0  30.0    Male              15.0     Finance
# 3609       49640.0  55.0    Male               9.0     Finance
# 8346       16017.0  27.0  Female               9.0  Technology
# ...            ...   ...     ...               ...         ...
# 68241      62836.0  42.0    Male              14.0     Finance
# 69990      44579.0  39.0    Male               4.0     Finance
# 71960      12284.0  24.0    Male              12.0  Technology
# 72273       3283.0  59.0    Male              34.0     Finance
# 74052      44059.0  58.0  Female              27.0     Finance
#
#        Monthly Income Work-Life Balance Job Satisfaction Performance Rating  \
# 387           15495.0              Poor              Low            Average
# ...

# %%
# Impute outliers with median for a specific column
median_income = df['Monthly Income'].median()
df['Monthly Income'] = np.where(df['Monthly Income'] > (Q3 + 1.5 * IQR), median_income, df['Monthly Income'])

# %%
# Impute outliers with median for a specific column
median_income = df['Monthly Income'].median()

# Calculate Q1, Q3, and IQR for 'Monthly Income'
Q1 = df['Monthly Income'].quantile(0.25)
Q3 = df['Monthly Income'].quantile(0.75)
IQR = Q3 - Q1

df['Monthly Income'] = np.where(df['Monthly Income'] > (Q3 + 1.5 * IQR), median_income, df['Monthly Income'])

# %%
# Cap values at a specified threshold
threshold_upper = df['Monthly Income'].quantile(0.95)
df['Monthly Income'] = np.where(df['Monthly Income'] > threshold_upper, threshold_upper, df['Monthly Income'])

# %%
# Check the summary statistics before and after treatment
print(df[['Age', 'Monthly Income']].describe())

# Re-plot data to visualize changes
sns.boxplot(df['Age'])
plt.show()
# Out:
#                 Age  Monthly Income
# count  74498.000000    74498.000000
# mean      38.529746     7254.450925
# std       12.083456     2065.587802
# min       18.000000     1226.000000
# 25%       28.000000     5652.000000
# 50%       39.000000     7348.000000
# 75%       49.000000     8870.000000
# max       59.000000    10797.000000

# %%
# Check the summary statistics before and after treatment
print(df[['Age', 'Monthly Income']].describe())

# Re-plot data to visualize changes
sns.boxplot(data=df[['Age', 'Monthly Income']]) # Pass columns as a list
plt.show()
# Out:
#                 Age  Monthly Income
# count  74498.000000    74498.000000
# mean      38.529746     7254.450925
# std       12.083456     2065.587802
# min       18.000000     1226.000000
# 25%       28.000000     5652.000000
# 50%       39.000000     7348.000000
# 75%       49.000000     8870.000000
# max       59.000000    10797.000000

# %%
for i in df.select_dtypes(include="number").columns:
  sns.boxplot(data=df,x=i)
  plt.show()

# %%
#Ouatlier treatment have been done for the data set

# %%
#check for null values

# %%
df.isnull().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %%
#check for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#the data set if free of outliers and duplicates null values
#the data set is clean

# %%
#now for the encoding part

# %%
df.head()
# Out:
#    Employee ID   Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0       8410.0  31.0    Male              19.0   Education          5390.0
# 1      64756.0  59.0  Female               4.0       Media          5534.0
# 2      30257.0  24.0  Female              10.0  Healthcare          8159.0
# 3      65791.0  36.0  Female               7.0   Education          3989.0
# 4      65026.0  56.0    Male              41.0   Education          4821.0
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize label encoder
label_encoder = LabelEncoder()

# Encode categorical columns
categorical_cols = ['Gender', 'Job Role', 'Work-Life Balance', 'Job Satisfaction', 'Performance Rating',
                    'Overtime','Education Level','Marital Status','Job Level',
                     'Company Size', 'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
                     'Company Reputation', 'Employee Recognition', 'Attrition']

for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# %%
df.head(70)
# Out:
#     Employee ID   Age  Gender  Years at Company  Job Role  Monthly Income  \
# 0        8410.0  31.0       1              19.0         0          5390.0
# 1       64756.0  59.0       0               4.0         3          5534.0
# 2       30257.0  24.0       0              10.0         2          8159.0
# 3       65791.0  36.0       0               7.0         0          3989.0
# 4       65026.0  56.0       1              41.0         0          4821.0
# ..          ...   ...     ...               ...       ...             ...
# 65      70231.0  50.0       1              35.0         1          7303.0
# 66      65665.0  29.0       1               8.0         1          7946.0
# 67      64242.0  27.0       1              14.0         1          6026.0
# 68      23287.0  48.0       1               1.0         4         10135.0
# 69      12556.0  47.0       1              24.0         2          8631.0
#
#     Work-Life Balance  Job Satisfaction  Performance Rating  \
# ...

# %%
#scaling the data  we got

# %%
from sklearn.preprocessing import StandardScaler

# Initialize scaler
scaler = StandardScaler()
numerical_cols = ['Age', 'Years at Company', 'Monthly Income', 'Number of Promotions','Distance from Home', 'Number of Dependents',
                   'Job Level', 'Company Tenure']

df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
df.head()
# Out:
#    Employee ID       Age  Gender  Years at Company  Job Role  Monthly Income  \
# 0       8410.0 -0.623149       1          0.292097         0       -0.902631
# 1      64756.0  1.694084       0         -1.044365         3       -0.832917
# 2      30257.0 -1.202458       0         -0.509780         2        0.437917
# 3      65791.0 -0.209358       0         -0.777072         0       -1.580893
# 4      65026.0  1.445809       1          2.252240         0       -1.178099
#
#    Work-Life Balance  Job Satisfaction  Performance Rating  \
# 0                  0                 2                   0
# 1                  3                 0                   3
# 2                  2                 0                   3
# 3                  2                 0                   2
# 4                  1                 3                   0
#
#    Number of Promotions  Overtime  Distance from Home  Education Level  \
# 0              1.172564         0           -0.981699                0
# ...

# %%
#Build and evaluate a predictive model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
X = df.drop('Attrition', axis=1)
y = df['Attrition']

# %%
X.head()
# Out:
#    Employee ID       Age  Gender  Years at Company  Job Role  Monthly Income  \
# 0       8410.0 -0.623149       1          0.292097         0       -0.902631
# 1      64756.0  1.694084       0         -1.044365         3       -0.832917
# 2      30257.0 -1.202458       0         -0.509780         2        0.437917
# 3      65791.0 -0.209358       0         -0.777072         0       -1.580893
# 4      65026.0  1.445809       1          2.252240         0       -1.178099
#
#    Work-Life Balance  Job Satisfaction  Performance Rating  \
# 0                  0                 2                   0
# 1                  3                 0                   3
# 2                  2                 0                   3
# 3                  2                 0                   2
# 4                  1                 3                   0
#
#    Number of Promotions  Overtime  Distance from Home  Education Level  \
# 0              1.172564         0           -0.981699                0
# ...

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Attrition, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'SVM': SVC()
}

# %%
# Train and evaluate models
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print(f"Model: {name}")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print("\n")
# Out:
# Model: Logistic Regression
# [[7156 3506]
#  [3686 8002]]
#               precision    recall  f1-score   support
#
#            0       0.66      0.67      0.67     10662
#            1       0.70      0.68      0.69     11688
#
#     accuracy                           0.68     22350
#    macro avg       0.68      0.68      0.68     22350
# weighted avg       0.68      0.68      0.68     22350
#
#
#
# Model: Decision Tree
# [[6907 3755]
#  [3743 7945]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65     10662
#            1       0.68      0.68      0.68     11688
#
#     accuracy                           0.66     22350
#    macro avg       0.66      0.66      0.66     22350
# weighted avg       0.66      0.66      0.66     22350
#
#
#
# Model: Random Forest
# [[7768 2894]
#  [2740 8948]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73     10662
# ...

# %%
importances = models['Random Forest'].feature_importances_
features = X.columns

# Create a DataFrame for feature importances
importance_df = pd.DataFrame({'Feature': features, 'Importance': importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

print(importance_df)
# Out:
#                      Feature  Importance
# 15                 Job Level    0.095952
# 13            Marital Status    0.084430
# 11        Distance from Home    0.078729
# 0                Employee ID    0.076067
# 5             Monthly Income    0.073555
# 17            Company Tenure    0.070179
# 1                        Age    0.064459
# 3           Years at Company    0.064071
# 18               Remote Work    0.047527
# 6          Work-Life Balance    0.041975
# 14      Number of Dependents    0.038704
# 12           Education Level    0.038229
# 9       Number of Promotions    0.034739
# 4                   Job Role    0.028816
# 21        Company Reputation    0.027493
# 22      Employee Recognition    0.025893
# 7           Job Satisfaction    0.024350
# 8         Performance Rating    0.022643
# 16              Company Size    0.021264
# 2                     Gender    0.014232
# 10                  Overtime    0.011910
# 20  Innovation Opportunities    0.009588
# ...

# %%
model.predict(X_test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# Reshape the input into a 2D array (assuming 23 features)
input_data = [[	8410.0	,-0.623149	,1,	0.292097,	0	,-0.902638	,0,	2	,0	,1.172564	,0	,-0.981699	,0,	1	,-1.062252	,0.263885,	1	,1.309985	,0,	0	,0	,0	,2]]

# Make the prediction
y_pred = model.predict(input_data)

print(y_pred)
# Out:
# [1]

# %%
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[    0 10662]
#  [    0 11688]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     10662
#            1       0.52      1.00      0.69     11688
#
#     accuracy                           0.52     22350
#    macro avg       0.26      0.50      0.34     22350
# weighted avg       0.27      0.52      0.36     22350

# %%
#Hyperpara meter tuning codes

# %%
from sklearn.model_selection import GridSearchCV

# %%
log_reg_params = {
    'C': [0.01, 0.1, 1, 10, 100],  # Regularization strength
    'solver': ['liblinear', 'saga']  # Optimization algorithms
}

# %%
decision_tree_params = {
    'criterion': ['gini', 'entropy'],  # Measure of quality
    'max_depth': [None, 10, 20, 30],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10]  # Minimum samples required to split a node
}

# %%
random_forest_params = {
    'n_estimators': [50, 100, 200],  # Number of trees in the forest
    'max_depth': [None, 10, 20, 30],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10]  # Minimum samples required to split a node
}

# %%
# Example for Logistic Regression
grid_search = GridSearchCV(LogisticRegression(max_iter=1000), log_reg_params, cv=5, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best Parameters for Logistic Regression:", grid_search.best_params_)
# Out:
# Best Parameters for Logistic Regression: {'C': 0.01, 'solver': 'liblinear'}

# %%
best_log_reg = grid_search.best_estimator_
y_pred = best_log_reg.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[7473 3189]
#  [3400 8288]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.70      0.69     10662
#            1       0.72      0.71      0.72     11688
#
#     accuracy                           0.71     22350
#    macro avg       0.70      0.71      0.70     22350
# weighted avg       0.71      0.71      0.71     22350

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

def evaluate_models(data, target_column='Attrition'):
    # Define features and target variable
    X = data.drop(target_column, axis=1)
    y = data[target_column]

    # Encode categorical variables if necessary
    X = pd.get_dummies(X, drop_first=True)

    # Split the data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Initialize models
    models = {
        'Logistic Regression': LogisticRegression(max_iter=1000),
        'Decision Tree': DecisionTreeClassifier(),
        'Random Forest': RandomForestClassifier(),
        'SVM': SVC()
    }

    # Define hyperparameter grids
    param_grids = {
        'Logistic Regression': {
            'C': [0.1, 1, 10],
            'penalty': ['l2']
        },
        'Decision Tree': {
            'max_depth': [None, 10, 20, 30],
            'min_samples_split': [2, 5, 10]
        },
        'Random Forest': {
            'n_estimators': [100, 200, 300],
            'max_depth': [None, 10, 20],
            'min_samples_split': [2, 5, 10]
        },
        'SVM': {
            'C': [0.1, 1, 10],
            'kernel': ['linear', 'rbf']
        }
    }

    # Train and evaluate models
    results = {}
    for name, model in models.items():
        print(f"Training and evaluating {name}...")

        # Hyperparameter tuning
        grid_search = GridSearchCV(model, param_grids[name], cv=5, scoring='accuracy', n_jobs=-1)
        grid_search.fit(X_train, y_train)

        best_model = grid_search.best_estimator_
        y_pred = best_model.predict(X_test)

        # Collect results
        results[name] = {
            'Best Parameters': grid_search.best_params_,
            'Confusion Matrix': confusion_matrix(y_test, y_pred),
            'Classification Report': classification_report(y_test, y_pred)
        }

    # Print results
    for name, result in results.items():
        print(f"\nModel: {name}")
        print("Best Parameters:", result['Best Parameters'])
        print("Confusion Matrix:\n", result['Confusion Matrix'])
        print("Classification Report:\n", result['Classification Report'])

    return results

# Example usage:
# import pandas as pd
# data = pd.read_csv('your_data.csv')
# results = evaluate_models(data)

# %%
# Install required packages (if not already installed)
# !pip install scikit-learn

import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# Generate a sample dataset for testing
def generate_sample_data(n_samples=1000, n_features=20):
    X, y = make_classification(n_samples=n_samples, n_features=n_features, random_state=42)
    column_names = [f'Feature_{i}' for i in range(n_features)]
    data = pd.DataFrame(X, columns=column_names)
    data['Attrition'] = y
    return data

# Define the model evaluation function
def evaluate_models(data, target_column='Attrition'):
    # Define features and target variable
    X = data.drop(target_column, axis=1)
    y = data[target_column]

    # Split the data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Initialize models
    models = {
        'Logistic Regression': LogisticRegression(max_iter=1000),
        'Decision Tree': DecisionTreeClassifier(),
        'Random Forest': RandomForestClassifier(),
        'SVM': SVC()
    }

    # Define hyperparameter grids
    param_grids = {
        'Logistic Regression': {
            'C': [0.1, 1, 10],
            'penalty': ['l2']
        },
        'Decision Tree': {
            'max_depth': [None, 10, 20, 30],
            'min_samples_split': [2, 5, 10]
        },
        'Random Forest': {
            'n_estimators': [100, 200, 300],
            'max_depth': [None, 10, 20],
            'min_samples_split': [2, 5, 10]
        },
        'SVM': {
            'C': [0.1, 1, 10],
            'kernel': ['linear', 'rbf']
        }
    }

    # Train and evaluate models
    results = {}
    for name, model in models.items():
        print(f"Training and evaluating {name}...")

        # Hyperparameter tuning
        grid_search = GridSearchCV(model, param_grids[name], cv=5, scoring='accuracy', n_jobs=-1)
        grid_search.fit(X_train, y_train)

        best_model = grid_search.best_estimator_
        y_pred = best_model.predict(X_test)

        # Collect results
        results[name] = {
            'Best Parameters': grid_search.best_params_,
            'Confusion Matrix': confusion_matrix(y_test, y_pred),
            'Classification Report': classification_report(y_test, y_pred)
        }

    # Print results
    for name, result in results.items():
        print(f"\nModel: {name}")
        print("Best Parameters:", result['Best Parameters'])
        print("Confusion Matrix:\n", result['Confusion Matrix'])
        print("Classification Report:\n", result['Classification Report'])

    return results

# Example usage and test case
if __name__ == "__main__":
    # Generate sample data
    data = generate_sample_data()

    # Evaluate models
    results = evaluate_models(data)

    # Optionally: Write results to a file or perform additional assertions here
    # For example, you might want to assert the presence of specific metrics
    # based on known results or expected outcomes from the models.
# Out:
# ...
# Training and evaluating Logistic Regression...
# Training and evaluating Decision Tree...
# Training and evaluating Random Forest...
# Training and evaluating SVM...
#
# Model: Logistic Regression
# Best Parameters: {'C': 0.1, 'penalty': 'l2'}
# Confusion Matrix:
#  [[128  17]
#  [ 29 126]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       145
#            1       0.88      0.81      0.85       155
#
#     accuracy                           0.85       300
#    macro avg       0.85      0.85      0.85       300
# weighted avg       0.85      0.85      0.85       300
#
#
# Model: Decision Tree
# Best Parameters: {'max_depth': None, 'min_samples_split': 5}
# Confusion Matrix:
#  [[125  20]
#  [ 28 127]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       145
#            1       0.86      0.82      0.84       155
#
# ...
